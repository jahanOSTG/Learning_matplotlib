# %%
import numpy as np
import matplotlib.pyplot as plt
#plot1
x=np.array([10,20,30,40])
y=np.array([100,120,110,150])
plt.bar(x,y,width=5)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
#plot1
x=np.array([10,20,30,40])
y=np.array([100,120,110,150])
plt.bar(x,y,color='hotpink')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
#plot1
x=np.array([10,20,30,40])
y=np.array([100,120,110,150])
plt.subplot(1,2,1)
plt.bar(x,y,width=1)
#plot2
x=np.array([50,60,70,80])
y=np.array([130,120,110,150])
plt.subplot(1,2,2)
plt.bar(x,y)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
#plot1
x=np.array([10,20,30,40])
y=np.array([100,120,110,150])
plt.subplot(2,1,1)
plt.barh(x,y)
#plot2
x=np.array([50,60,70,80])
y=np.array([130,120,110,150])
plt.subplot(2,1,2)
plt.bar(x,y)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
#plot1
x=np.array([10,20,30,40])
y=np.array([100,120,110,150])
plt.subplot(2,2,1)
plt.bar(x,y,width=2,color='purple')
#plot2
x=np.array([50,60,70,80])
y=np.array([120,120,10,150])
plt.subplot(2,2,2)
plt.bar(x,y,width=2,color='green')
#plot3
x=np.array([90,100,110,120])
y=np.array([117,120,110,110])
plt.subplot(2,2,3)
plt.bar(x,y,width=2,color='hotpink')
#plot4
x=np.array([130,140,150,160])
y=np.array([160,110,110,150])
plt.subplot(2,2,4)
plt.bar(x,y,width=2,color='cyan')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 10, 1, 10])

plt.subplot(2, 3, 1)
plt.bar(x, y, width=2)

x = np.array([0, 1, 2, 3])
y = np.array([11, 20, 38, 40])

plt.subplot(2, 3, 2)
plt.bar(x, y, width=2)

x = np.array([0, 1, 2, 3])
y = np.array([10, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.bar(x, y, width=2)

x = np.array([0, 1, 2, 3])
y = np.array([10, 28, 30, 40])

plt.subplot(2, 3, 4)
plt.bar(x, y, width=2)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.bar(x, y, width=2)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.bar(x, y, width=2)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
#plot1
x=np.array([10,20,30,40])
y=np.array([100,120,110,150])
plt.subplot(1,2,1)
plt.bar(x, y, width=2)
plt.title("Fish Rate")
#plot2
x=np.array([50,60,70,80])
y=np.array([130,120,110,150])
plt.subplot(1,2,2)
plt.bar(x, y, width=2)
plt.title("Chicken Rate")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
#plot1
x=np.array([10,20,30,40])
y=np.array([100,120,110,150])
plt.subplot(1,2,1)

plt.barh(x, y, height = 0.1)
plt.title("Fish Rate")
#plot2
x=np.array([50,60,70,80])
y=np.array([130,120,110,150])
plt.subplot(1,2,2)

plt.barh(x, y, height = 0.1)
plt.title("Chicken Rate")

plt.suptitle("Total Protine Rate")
plt.show()
